# %%
import warnings

warnings.simplefilter("ignore")

import os
import sys

folder = os.getcwd().split("\\examples")[0]
sys.path.append(folder)

from sloyka import TopicModeler
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sandro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-19 14:36:51.284 | INFO     | sloyka.src.topic_modeler:process_topics:41 - Processing date: 2024-03-01 00:00:00
# 2024-04-19 14:37:02.122 | INFO     | sloyka.src.topic_modeler:process_topics:41 - Processing date: 2024-03-02 00:00:00
# 2024-04-19 14:37:05.448 | INFO     | sloyka.src.topic_modeler:process_topics:41 - Processing date: 2024-03-03 00:00:00
# 2024-04-19 14:37:10.258 | INFO     | sloyka.src.topic_modeler:process_topics:41 - Processing date: 2024-03-04 00:00:00
# 2024-04-19 14:37:16.359 | INFO     | sloyka.src.topic_modeler:process_topics:41 - Processing date: 2024-03-05 00:00:00

# %%
import geopandas as gpd
import pandas as pd
gdf = gpd.read_file("F:/Coding/all_parsed_11_04_2024_parser_1.1_fixed.geojson")

# %%
start_date = gdf['date'].min()
end_date = start_date + pd.Timedelta(days=7)
topic_modeler = TopicModeler(gdf, start_date, end_date)
df_clusters = topic_modeler.process_topics()
# Out:
# 04-19 14:38 | INFO     | Processing date: 2020-08-10 11:08:21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\bertopic\_bertopic.py:3355, in BERTopic._reduce_dimensionality(self, embeddings, y, partial_fit)
#    3354     y = np.array(y) if y is not None else None
# -> 3355     self.umap_model.fit(embeddings, y=y)
#    3356 except TypeError:
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:2780, in UMAP.fit(self, X, y, force_all_finite)
#    2777 epochs = (
#    2778     self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2779 )
# -> 2780 self.embedding_, aux_data = self._fit_embed_data(
#    2781     self._raw_data[index],
#    2782     epochs,
#    2783     init,
#    2784     random_state,  # JH why raw data?
#    2785 )
#    2787 if self.n_epochs_list is not None:
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:2826, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state)
#    2823 """A method wrapper for simplicial_set_embedding that can be
#    2824 replaced by subclasses.
#    2825 """
# -> 2826 return simplicial_set_embedding(
#    2827     X,
#    2828     self.graph_,
#    2829     self.n_components,
#    2830     self._initial_alpha,
#    2831     self._a,
#    2832     self._b,
#    2833     self.repulsion_strength,
#    2834     self.negative_sample_rate,
#    2835     n_epochs,
#    2836     init,
#    2837     random_state,
#    2838     self._input_distance_func,
#    2839     self._metric_kwds,
#    2840     self.densmap,
#    2841     self._densmap_kwds,
#    2842     self.output_dens,
#    2843     self._output_distance_func,
#    2844     self._output_metric_kwds,
#    2845     self.output_metric in ("euclidean", "l2"),
#    2846     self.random_state is None,
#    2847     self.verbose,
#    2848     tqdm_kwds=self.tqdm_kwds,
#    2849 )
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:1106, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1105 elif isinstance(init, str) and init == "spectral":
# -> 1106     embedding = spectral_layout(
#    1107         data,
#    1108         graph,
#    1109         n_components,
#    1110         random_state,
#    1111         metric=metric,
#    1112         metric_kwds=metric_kwds,
#    1113     )
#    1114     # We add a little noise to avoid local minima for optimization to come
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     273 """
#     274 Given a graph compute the spectral embedding of the graph. This is
#     275 simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)
#     302     The spectral embedding of the graph.
#     303 """
# --> 304 return _spectral_layout(
#     305     data=data,
#     306     graph=graph,
#     307     dim=dim,
#     308     random_state=random_state,
#     309     metric=metric,
#     310     metric_kwds=metric_kwds,
#     311     init="random",
#     312     tol=tol,
#     313     maxiter=maxiter
#     314 )
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\spectral.py:521, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     520 if method == "eigsh":
# --> 521     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     522         L,
#     523         k,
#     524         which="SM",
#     525         ncv=num_lanczos_vectors,
#     526         tol=tol or 1e-4,
#     527         v0=np.ones(L.shape[0]),
#     528         maxiter=maxiter or graph.shape[0] * 5,
#     529     )
#     530 elif method == "lobpcg":
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1608, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1607 if issparse(A):
# -> 1608     raise TypeError("Cannot use scipy.linalg.eigh for sparse A with "
#    1609                     "k >= N. Use scipy.linalg.eigh(A.toarray()) or"
#    1610                     " reduce k.")
#    1611 if isinstance(A, LinearOperator):
#
# TypeError: Cannot use scipy.linalg.eigh for sparse A with k >= N. Use scipy.linalg.eigh(A.toarray()) or reduce k.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 end_date = start_date + pd.Timedelta(days=7)
#       3 topic_modeler = TopicModeler(gdf, start_date, end_date)
# ----> 4 df_clusters = topic_modeler.process_topics()
#
# File f:\Coding\sloyka\sloyka\src\topic_modeler.py:48, in TopicModeler.process_topics(self)
#      46 docs = current_df.text.to_list()
#      47 # Create clusters for the current date
# ---> 48 current_topic_model = self.create_topic_model(docs)
#      50 if single_date.date() == self.date_range[0].date():
#      51     self.global_model = current_topic_model
#
# File f:\Coding\sloyka\sloyka\src\topic_modeler.py:78, in TopicModeler.create_topic_model(self, docs)
#      77 def create_topic_model(self, docs):
# ---> 78     return BERTopic(embedding_model=self.embedding_model, umap_model=self.umap_model).fit(docs)
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\bertopic\_bertopic.py:316, in BERTopic.fit(self, documents, embeddings, images, y)
#     275 def fit(self,
#     276         documents: List[str],
#     277         embeddings: np.ndarray = None,
#     278         images: List[str] = None,
#     279         y: Union[List[int], np.ndarray] = None):
#     280     """ Fit the models (Bert, UMAP, and, HDBSCAN) on a collection of documents and generate topics
#     281
#     282     Arguments:
#    (...)
#     314     ```
#     315     """
# --> 316     self.fit_transform(documents=documents, embeddings=embeddings, y=y, images=images)
#     317     return self
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\bertopic\_bertopic.py:408, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     405         return self._combine_zeroshot_topics(documents, assigned_documents, assigned_embeddings)
#     407 # Reduce dimensionality
# --> 408 umap_embeddings = self._reduce_dimensionality(embeddings, y)
#     410 # Cluster reduced embeddings
#     411 documents, probabilities = self._cluster_embeddings(umap_embeddings, documents, y=y)
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\bertopic\_bertopic.py:3358, in BERTopic._reduce_dimensionality(self, embeddings, y, partial_fit)
#    3355         self.umap_model.fit(embeddings, y=y)
#    3356     except TypeError:
# -> 3358         self.umap_model.fit(embeddings)
#    3360 umap_embeddings = self.umap_model.transform(embeddings)
#    3361 logger.info("Dimensionality - Completed \u2713")
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:2780, in UMAP.fit(self, X, y, force_all_finite)
#    2776 if self.transform_mode == "embedding":
#    2777     epochs = (
#    2778         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2779     )
# -> 2780     self.embedding_, aux_data = self._fit_embed_data(
#    2781         self._raw_data[index],
#    2782         epochs,
#    2783         init,
#    2784         random_state,  # JH why raw data?
#    2785     )
#    2787     if self.n_epochs_list is not None:
#    2788         if "embedding_list" not in aux_data:
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:2826, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state)
#    2822 def _fit_embed_data(self, X, n_epochs, init, random_state):
#    2823     """A method wrapper for simplicial_set_embedding that can be
#    2824     replaced by subclasses.
#    2825     """
# -> 2826     return simplicial_set_embedding(
#    2827         X,
#    2828         self.graph_,
#    2829         self.n_components,
#    2830         self._initial_alpha,
#    2831         self._a,
#    2832         self._b,
#    2833         self.repulsion_strength,
#    2834         self.negative_sample_rate,
#    2835         n_epochs,
#    2836         init,
#    2837         random_state,
#    2838         self._input_distance_func,
#    2839         self._metric_kwds,
#    2840         self.densmap,
#    2841         self._densmap_kwds,
#    2842         self.output_dens,
#    2843         self._output_distance_func,
#    2844         self._output_metric_kwds,
#    2845         self.output_metric in ("euclidean", "l2"),
#    2846         self.random_state is None,
#    2847         self.verbose,
#    2848         tqdm_kwds=self.tqdm_kwds,
#    2849     )
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\umap_.py:1106, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1102     embedding = noisy_scale_coords(
#    1103         embedding, random_state, max_coord=10, noise=0.0001
#    1104     )
#    1105 elif isinstance(init, str) and init == "spectral":
# -> 1106     embedding = spectral_layout(
#    1107         data,
#    1108         graph,
#    1109         n_components,
#    1110         random_state,
#    1111         metric=metric,
#    1112         metric_kwds=metric_kwds,
#    1113     )
#    1114     # We add a little noise to avoid local minima for optimization to come
#    1115     embedding = noisy_scale_coords(
#    1116         embedding, random_state, max_coord=10, noise=0.0001
#    1117     )
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     263 def spectral_layout(
#     264     data,
#     265     graph,
#    (...)
#     271     maxiter=0
#     272 ):
#     273     """
#     274     Given a graph compute the spectral embedding of the graph. This is
#     275     simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)
#     302         The spectral embedding of the graph.
#     303     """
# --> 304     return _spectral_layout(
#     305         data=data,
#     306         graph=graph,
#     307         dim=dim,
#     308         random_state=random_state,
#     309         metric=metric,
#     310         metric_kwds=metric_kwds,
#     311         init="random",
#     312         tol=tol,
#     313         maxiter=maxiter
#     314     )
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\umap\spectral.py:521, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     518 X[:, 0] = sqrt_deg / np.linalg.norm(sqrt_deg)
#     520 if method == "eigsh":
# --> 521     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     522         L,
#     523         k,
#     524         which="SM",
#     525         ncv=num_lanczos_vectors,
#     526         tol=tol or 1e-4,
#     527         v0=np.ones(L.shape[0]),
#     528         maxiter=maxiter or graph.shape[0] * 5,
#     529     )
#     530 elif method == "lobpcg":
#     531     with warnings.catch_warnings():
#
# File c:\Users\Sandro\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1608, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1603 warnings.warn("k >= N for N * N square matrix. "
#    1604               "Attempting to use scipy.linalg.eigh instead.",
#    1605               RuntimeWarning, stacklevel=2)
#    1607 if issparse(A):
# -> 1608     raise TypeError("Cannot use scipy.linalg.eigh for sparse A with "
#    1609                     "k >= N. Use scipy.linalg.eigh(A.toarray()) or"
#    1610                     " reduce k.")
#    1611 if isinstance(A, LinearOperator):
#    1612     raise TypeError("Cannot use scipy.linalg.eigh for LinearOperator "
#    1613                     "A with k >= N.")
#
# TypeError: Cannot use scipy.linalg.eigh for sparse A with k >= N. Use scipy.linalg.eigh(A.toarray()) or reduce k.
