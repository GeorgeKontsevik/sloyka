# %%
import warnings

warnings.simplefilter("ignore")

import os
import sys

folder = os.getcwd().split("\\examples")[0]
sys.path.append(folder)

from sloyka import TopicModeler
# Out:
# INFO: Pandarallel will run on -1 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sandro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import geopandas as gpd
import pandas as pd
gdf = gpd.read_file("F:/Coding/all_parsed_11_04_2024_parser_1.1_fixed.geojson")

# %%
start_date = '2024-03-01'
end_date = '2024-03-06'
topic_modeler = TopicModeler(gdf, start_date, end_date)
df_clusters = topic_modeler.process_topics()
# Out:
# 04-24 15:31 | INFO     | Processing date: 2024-03-01 00:00:00
# 04-24 15:31 | INFO     | Processing date: 2024-03-02 00:00:00
# 04-24 15:32 | INFO     | Processing date: 2024-03-03 00:00:00
# 04-24 15:32 | INFO     | Processing date: 2024-03-04 00:00:00
# 04-24 15:32 | INFO     | Processing date: 2024-03-05 00:00:00
# 04-24 15:32 | INFO     | Processing date: 2024-03-06 00:00:00

# %%
df_clusters.cluster_name.unique()
# Out:
# array(['0_на_не_по_за', '1_ломоносова_мост_коломенская_',
#        '5_не_как_то_ну', '2_на_по_что_не', '1_так_земля_да_все',
#        '0_какой_что_бы_сказать', '4_здравствуйте_группы_можем_деньги',
#        '7_выступление_песочный_2023_отчете',
#        '3_спасибо_большое_спектакль_благодарю',
#        '6_жду_проходе_новости_скажешь', '0_не_на_что_по',
#        '1_следом_домики_невским_за', '12_https_vk_com_me',
#        '2_на_по_марта_для', '10_пробито_малоохтинском_скорости_тротуару',
#        '0_не_так_что_как', '11_провода_электрощиток_цветной_вандализм',
#        '7_алкоголики_арок_местные_пятнашкой',
#        '3_вот_обкорнали_страшно_похоже', '5_вы_носорогов_смотрю_на',
#        '1_что_было_подскажите_же', '9_спасибо_большое_благодарю_архиве',
#        '8_18_32_конная_24', '6_поиграть_могyт_лиговский_рояле',
#        '4_здравствуйте_за_нам_спектакль', '0_не_на_что_это',
#        '1_спасибо_спектакль_молодцы_удачи', '4_так_не_нет_но',
#        '5_автово_россети_до_оповещения', '3_какие_ли_доброе_личку',
#        '7_билеты_на_билет_здравствуйте', '2_на_по_от_не',
#        '6_кирпич_согласен_ответила_закончились', '8_https_com_wall_ru',
#        '1_на_по_не_что'], dtype=object)

# %%
df_clusters.head(5)
# Out:
#    level_0  index        date      id  \
# 0     5996     47  2024-03-01   27739
# 1     7100     14  2024-03-01   50912
# 2    12865     50  2024-03-01  331147
# 3    12865     50  2024-03-01  331147
# 4    12865     50  2024-03-01  331147
#
#                                                 text  views.count  \
# 0  УСТРАНЕНИЕ ПРОДУВАНИЙ, ПРОТЕЧЕК ОКОН, ЛОДЖИЙ. ...          NaN
# 1  ВНИМАНИЕ! ПОМОГИТЕ НАЙТИ ЧЕЛОВЕКА!Максимальный...       5142.0
# 2  Мелочь, а приятно! , недавно обнаруженную нами...       2294.0
# 3  Мелочь, а приятно! , недавно обнаруженную нами...       2294.0
# 4  Мелочь, а приятно! , недавно обнаруженную нами...       2294.0
#
#    likes.count  reposts.count  type  \
# 0          0.0            0.0  post
# 1         50.0           20.0  post
# 2         52.0            3.0  post
# 3         52.0            3.0  post
# 4         52.0            3.0  post
#
#                                                link  ...  \
# 0  https://vk.com/teploeosteklenie812[Ссылка]Замена  ...
# 1                                               NaN  ...
# 2     https://vk.com/wall-129354225_329416|Кроличью  ...
# 3     https://vk.com/wall-129354225_329416|Кроличью  ...
# 4     https://vk.com/wall-129354225_329416|Кроличью  ...
#
#                                     full_street_name  \
# 0
# 1
# 2  улица Восстания 30 Санкт-Петербург Россия,площ...
# 3  улица Восстания 30 Санкт-Петербург Россия,площ...
# 4  улица Восстания 30 Санкт-Петербург Россия,площ...
#
#                                     location_options  \
# 0                                                 []
# 1                                                 []
# 2  [улица Восстания 30 Санкт-Петербург Россия, пл...
# 3  [улица Восстания 30 Санкт-Петербург Россия, пл...
# 4  [улица Восстания 30 Санкт-Петербург Россия, пл...
#
#                                addr_to_geocode  only_full_street_name  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2    улица Восстания 30 Санкт-Петербург Россия        улица Восстания
# 3    улица Восстания 30 Санкт-Петербург Россия      площадь Восстания
# 4  площадь Восстания 30 Санкт-Петербург Россия        улица Восстания
#
#   only_full_street_name_numbers  \
# 0                           NaN
# 1                           NaN
# 2            улица Восстания 30
# 3          площадь Восстания 30
# 4            улица Восстания 30
#
#                                             Location  \
# 0                                                NaN
# 1                                                NaN
# 2  33, 30, улица Восстания, Литейный округ, Санкт...
# 3  33, 30, улица Восстания, Литейный округ, Санкт...
# 4  площадь Восстания, округ Лиговка-Ямская, Санкт...
#
#                     geometry   cluster_name cluster_probability cluster_id
# 0                       None  0_на_не_по_за                 1.0          0
# 1                       None  0_на_не_по_за                 1.0          0
# 2  POINT (30.36028 59.94012)  0_на_не_по_за                 1.0          0
# 3  POINT (30.36028 59.94012)  0_на_не_по_за                 1.0          0
# 4  POINT (30.36191 59.93077)  0_на_не_по_за                 1.0          0
#
# [5 rows x 27 columns]
